# %% [markdown]
# # Data Gathering

# %%
import requests
from bs4 import BeautifulSoup
base_url = "https://www.imoti.com/prodazhbi/"
cities = [
    "grad-sofiya",
    "grad-plovdiv",
    "grad-varna",
    "grad-burgas",
    "grad-ruse",
    "grad-stara-zagora",
    "grad-pleven",
    "grad-sliven",
    "grad-dobrich",
    "grad-shumen",
    "grad-pernik",
    "grad-haskovo",
    "grad-yambol",
    "grad-pazardzhik",
    "grad-blagoevgrad",
    "grad-veliko-tarnovo",
    "grad-vratsa",
    "grad-gabrovo",
    "grad-asenovgrad",
    "grad-vidin",
    "grad-kazanlak",
    "grad-kyustendil",
    "grad-montana",
    "grad-targovishte",
    "grad-kardzhali",
    "grad-silistra",
    "grad-lovech",
    "grad-dupnitsa",
    "grad-svishtov",
    "grad-razgrad",
    "grad-gorna-oryahovitsa"
] 
class Advertisement:
  def __init__(self, city, neighborhood, type, size, floor, gas, tpp, price):
    self.city = city
    self.neighborhood = neighborhood
    self.type = type,
    self.size = size,
    self.floor = floor,
    self.gas = gas,
    self.tpp = tpp,
    self.price = price

# %%
def get_advertisement_data(url):
    response = requests.get(current_url)
    soup = BeautifulSoup(response.text, 'html.parser')
    city = soup.find("div",{"class":"breadcrumbs"})
    print(soup.prettify())

for x in range(len(cities)): 
    current_url = base_url + cities[x]
    response = requests.get(current_url)
    
    soup = BeautifulSoup(response.text, 'html.parser')
    get_advertisement_data("https://www.imoti.com/obiava/92635799/prodava-1-staen-grad-sofiya-borovo")
    break
# Out:
# <!DOCTYPE html>
# <html lang="bg" prefix="og: http://ogp.me/ns#">
#  <head>
#   <meta charset="utf-8"/>
#   <title>
#    Имоти в 《  град София 》 Цени — Imoti.com
#   </title>
#   <meta content="Избери имот в  град София в Imoti.com ⇒ Пазарът за имоти в България. 2000 обяви за продажба на имот ⇒ цени от 45000 лв. актуални предложения ⇒  реални снимки ⇒ бърз отговор." name="description"/>
#   <link href="/favicon.ico?2" rel="SHORTCUT ICON"/>
#   <link href="https://www.imoti.com/prodazhbi/grad-sofiya" rel="canonical">
#    <link href="https://www.imoti.com/prodazhbi/grad-sofiya/page-2" rel="next"/>
#    <!--    <link rel="alternate" media="only screen and (max-width: 640px)"  href="https://m.imoti.com/prodazhbi/grad-sofiya">-->
#    <!--    <link rel="alternate" media="only screen and (max-width: 640px)"  href="https://m.imoti.com/prodazhbi/grad-sofiya">-->
#    <meta content="index,follow" name="robots"/>
#    <meta content="bg" property="og:locale">
# ...
