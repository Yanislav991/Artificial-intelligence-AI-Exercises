# %% [markdown]
# # Data Gathering

# %%
import requests
base_url = "https://www.imoti.com/prodazhbi/"
cities = [
    "grad-sofia",
    "grad-plovdiv",
    "grad-varna",
    "grad-burgas",
    "grad-ruse",
    "grad-stara-zagora",
    "grad-pleven",
    "grad-sliven",
    "grad-dobrich",
    "grad-shumen",
    "grad-pernik",
    "grad-haskovo",
    "grad-yambol",
    "grad-pazardzhik",
    "grad-blagoevgrad",
    "grad-veliko-tarnovo",
    "grad-vratsa",
    "grad-gabrovo",
    "grad-asenovgrad",
    "grad-vidin",
    "grad-kazanlak",
    "grad-kyustendil",
    "grad-montana",
    "grad-targovishte",
    "grad-kardzhali",
    "grad-silistra",
    "grad-lovech",
    "grad-dupnitsa",
    "grad-svishtov",
    "grad-razgrad",
    "grad-gorna-oryahovitsa"
]

# %%
for x in range(len(cities)): 
    response = requests.get(base_url)
    response.text
# Out:
# '<!DOCTYPE html>\n<html lang="bg">\n<head>\n<title>Èìîòè - Imot.bg - Ïàçàðúò íà íåäâèæèìè èìîòè - ïðîäàæáè, íàåìè, àãåíöèè, íîâèíè çà èìîòè (imoti)</title>\n<meta http-equiv="Content-Type" content="text/html; charset=windows-1251">\n<meta name="description" content="imot.bg - Ïàçàðúò íà íåäâèæèìè èìîòè â Áúëãàðèÿ. Îôåðòè çà ïðîäàæáà, ïîä íàåì, êóïóâà, íàåìà, çàìåíÿ. Àãåíöèè çà èìîòè. Íîâèíè. Ñúâåòè. Ñòðîèòåëñòâî. Îáçàâåæäàíå. Èíòåðèîð. Êðåäèòèðàíå è äð.">\n<link rel="SHORTCUT ICON" href="https://www.imot.bg/favicon.ico" />\n<link rel="stylesheet" href="../styless/styles.css?279" type="text/css">\n<script type="text/javascript" src="../jss/scripts.js?279"></script>\n<script type="text/javascript" src="../jss/dim.js?279"></script>\n<script type="text/javascript" src="../jss/mobile-detect.min.js?279"></script>\n<script type="text/javascript" src="../jss/jquery.min.js"></script>\n<script type="text/javascript">\n        var md = new MobileDetect(window.navigator.userAgent);\n        if (
# ...
